# %% [markdown]
# # Life Expectancy and GDP Analysis

# %% [markdown]
# In this project, we will visualize data on GDP and life expectancy from the World Health Organization and the World Bank to try and identify the relationship between the GDP and life expectancy of six countries.
#
# The dataset is saved as a csv file named `'all_data.csv'`. The data includes:
#
# - `Country`: the name of the nation
# - `Year`: the year the data was taken
# - `life expectancy at birth (years)`: the amount of years a person can expect to live in years
# - `GDP`: the gross domestic product of the nation

# %% [markdown]
# ## Inspect Dataset

# %%
#Import Libraries Required for Analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('all_data.csv')
df.head()
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
# Country                             96 non-null object
# Year                                96 non-null int64
# Life expectancy at birth (years)    96 non-null float64
# GDP                                 96 non-null float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.1+ KB

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Life expectancy at birth (years)', 'GDP'], dtype='object')

# %%
#let's rename our columns to make it easier while doing our analysis
df.rename(columns = {'Country': 'country', 'Year': 'year','Life expectancy at birth (years)':'life_expectancy','GDP':'gdp' }, inplace = True)
df.columns
# Out:
# Index(['country', 'year', 'life_expectancy', 'gdp'], dtype='object')

# %%
#let's check the nations and years we are going to be analyzing
print(df.country.unique())
print(df.year.unique())
# Out:
# ['Chile' 'China' 'Germany' 'Mexico' 'United States of America' 'Zimbabwe']
# [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015]

# %%
#Let's Replace the 'United States of America' with 'USA'
df.replace(to_replace = {'United States of America': 'USA'}, inplace = True)
df.country.unique()
# Out:
# array(['Chile', 'China', 'Germany', 'Mexico', 'USA', 'Zimbabwe'],
#       dtype=object)

# %%
#Let's take a deeper look at our numerical variables to see if we have missing variables
df.describe()
# Out:
#               year  life_expectancy           gdp
# count    96.000000        96.000000  9.600000e+01
# mean   2007.500000        72.789583  3.880499e+12
# std       4.633971        10.672882  5.197561e+12
# min    2000.000000        44.300000  4.415703e+09
# 25%    2003.750000        74.475000  1.733018e+11
# 50%    2007.500000        76.750000  1.280220e+12
# 75%    2011.250000        78.900000  4.067510e+12
# max    2015.000000        81.000000  1.810000e+13

# %% [markdown]
# #### We can conclude that we do not have any missing values in our dataset and can proceed to start our visualization

# %% [markdown]
# ## Data Visualization & Analysis

# %%
# Trend of life expectancy
plt.figure(figsize=(16,10))
ax = sns.lineplot(x = 'year', y = 'life_expectancy', data = df, hue = 'country', style = 'country' ,palette = 'colorblind', markers = True, dashes = False)
plt.xlabel('Year')
plt.ylabel('Life Expectancy at Birth (years)')
plt.title('Trend of Life Expectancy between 2000 and 2015')
plt.show()
plt.clf()

# %%
plt.figure(figsize=(16,10))
ax = sns.lineplot(x = 'year', y = 'gdp', data = df, hue = 'country', style = 'country' ,palette = 'colorblind', markers = True, dashes = False)
plt.xlabel('Year')
plt.ylabel('Gross Domestic Product (dollars)')
plt.title('Trend of GDP between 2000 and 2015')
plt.show()
plt.clf()

# %%
plt.figure(figsize=(16,10))
sns.scatterplot(x = 'life_expectancy', y= 'gdp', data = df)
plt.xlabel('Life Expectancy')
plt.ylabel('Gross Domestic Product (dollars)')
plt.title('Scatterplot of GDP against Life Expectancy')
plt.show()
plt.clf()

# %% [markdown]
# We can clearly see that GDP for Chile and Zimbabwe is relatively small when compared to other the other countries and it's difficult to spot the trends, if there are any.

# %%
#Let's take a closer look at the individual trends
palette = sns.color_palette("colorblind")
for country in df.country.unique():
    plt.figure(figsize = (20,8))
    plt.subplot(1,2,1)
    sns.lineplot(x = 'year', y = 'gdp', data = df[df.country == country], color = palette[list(df.country.unique()).index(country)] )
    plt.xlabel('Year')
    plt.ylabel('Gross Domestic Product (dollars)')
    plt.title("Trend of {}'s GDP between 2000 and 2015".format(country))
    plt.subplot(1,2,2)
    sns.lineplot(x = 'year', y = 'life_expectancy', data = df[df.country == country], color = palette[list(df.country.unique()).index(country)] )
    plt.xlabel('Year')
    plt.ylabel('Life Expectancy at Birth (years)')
    plt.title("Trend of {}'s Life Expectancy between 2000 and 2015".format(country))
    plt.show()
    plt.clf()

# %%
#let's look at the relationship between each country's GDP and Life Expectancy
fig_num = 0
plt.figure(figsize = (12,10))
plt.title('GDP against Life Expectancy')
for country in df.country.unique():
    fig_num  += 1
    plt.subplot(3,2,fig_num)
    sns.scatterplot(x = 'life_expectancy', y = 'gdp', data = df[df.country == country])
    plt.title('Country = {}'.format(country))
plt.tight_layout()    
plt.show()
plt.clf()

# %%
sns.histplot(x = 'life_expectancy', data = df, bins = 50)
plt.show()
plt.clf()

# %%
sns.boxplot(x = 'life_expectancy', data = df)
plt.show()
plt.clf()

# %% [markdown]
# Let's consider a few summary statistics

# %%
df.groupby('country').life_expectancy.mean()
# Out:
# country
# Chile       78.94375
# China       74.26250
# Germany     79.65625
# Mexico      75.71875
# USA         78.06250
# Zimbabwe    50.09375
# Name: life_expectancy, dtype: float64

# %%
df.groupby('country').gdp.mean()
# Out:
# country
# Chile       1.697888e+11
# China       4.957714e+12
# Germany     3.094776e+12
# Mexico      9.766506e+11
# USA         1.407500e+13
# Zimbabwe    9.062580e+09
# Name: gdp, dtype: float64

# %%
df.groupby('year').life_expectancy.mean()
# Out:
# year
# 2000    70.766667
# 2001    70.833333
# 2002    70.950000
# 2003    71.033333
# 2004    71.300000
# 2005    71.483333
# 2006    71.950000
# 2007    72.300000
# 2008    72.666667
# 2009    73.066667
# 2010    73.483333
# 2011    74.200000
# 2012    74.600000
# 2013    74.966667
# 2014    75.316667
# 2015    75.716667
# Name: life_expectancy, dtype: float64

# %%
df.groupby('year').gdp.mean()
# Out:
# year
# 2000    2.371583e+12
# 2001    2.448752e+12
# 2002    2.561221e+12
# 2003    2.743446e+12
# 2004    2.991647e+12
# 2005    3.207074e+12
# 2006    3.463349e+12
# 2007    3.785750e+12
# 2008    4.055986e+12
# 2009    4.000653e+12
# 2010    4.299587e+12
# 2011    4.710965e+12
# 2012    4.962082e+12
# 2013    5.269258e+12
# 2014    5.558059e+12
# 2015    5.658565e+12
# Name: gdp, dtype: float64

# %%
df[['life_expectancy','gdp']].corr()
# Out:
#                  life_expectancy       gdp
# life_expectancy         1.000000  0.343207
# gdp                     0.343207  1.000000

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The data used in this analysis is a clean dataset and didn't require preparations; however, I inspected it to check for missing observations, which shows no missing data. After examination, I visualized the data using phyton libraries matplotlib and seaborn. I used line graphs and scatter plots to visualize the trends from the year 2000 to the year 2015 and the relationships between two quantitative variables(GDP and life expectancy) over this period, respectively. The visualization was followed by finding the quantitative variables' mean by country and year.
#
# Generally, between the years 2000 and 2015, there was an increase in the life expectancy of people and GDP in the six countries considered. The average life expectancy of the six countries increased from 70.8 in 2000 to 75.7 in 2015. The life expectancy in Zimbabwe could be viewed as an outlier, as shown in the histogram and boxplot. Zimbabwe had the highest increase from about 45 years to over 60 years, indicating an approximately 25% increase in the number of years Zimbabweans expect to live. Besides having the lowest life expectancy, Zimbabwe has the lowest GDP over the years considered in this analysis.
#
# The USA remained the number one country GDP-wise over the 15 years. However, Germany was behind the USA until China overtook it in 2007 and remained the second economy behind the US. The scatterplots show a positive relationship between GDP and life expectancy for all nations considered. The calculation of a correlation of 0.34 further solidifies this relationship.
